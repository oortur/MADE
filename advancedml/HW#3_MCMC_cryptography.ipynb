# %% [markdown]
# # Advanced Machine Learning. Homework #3
#
# <br>
# Task text:
# <br>
#
# https://docs.google.com/document/d/1FWCuz-3Q_85yQYEwz6xVkIuXUjQn60dVFxreJId-liM/
# <br>

# %%
import re
import random
from copy import deepcopy

import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
with open("./WarAndPeace.txt", "r") as file:
    war_and_peace_ru = file.read().lower().replace("\n", " ")
    
with open("./WarAndPeaceEng.txt", "r") as file:
    war_and_peace_en = file.read().lower().replace("\n", " ")
    
with open("./AnnaKarenina.txt", "r") as file:
    anna_karenina = file.read().lower().replace("\n", " ")

# %%
# re.sub('\s+', ' ', some_text)

# %%
def create_ngram_list(text, ngram=1):
    pass

def create_freq_dict(tokens_list):
    pass

# %%
class MCMCDecoder:
    def __init__(self, base_freq_dict, input_text, ngram=2):
        self.base_freq_dict = base_freq_dict
        self.input_text = input_text
        self.ngram = ngram
        self.dict_size = len(self.input_freq_dict)
        self.decoding = {}
        self.cur_decoding = {}
    
    def shuffle_decoding(self):
        unk1, unk2 = np.random.choice(self.decoding.keys(), size=2, replace=False)
        self.cur_decoding[unk1], self.cur_decoding[unk2] = self.decoding[unk2], self.decoding[unk1]
    
    def _freqs_using_current_decoding(self):
        decoded_sym_list = [self.cur_decoding[sym] for sym in self.input_text]
        ngrams_list = [decoded_sym_list[start_ix : start_ix+self.ngram] for start_ix in range(len(decoded_sym_list) - self.ngram)]
        pass
        
    def decode(self, n_iter=10000):
        cur_decoding = self.decoding
        for i in range(n_iter):
            self.shuffle_decoding()
            pass
